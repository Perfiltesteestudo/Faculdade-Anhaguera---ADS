# %%
#@title Ficha de RPG - World of Warcraft

# Informações Básicas
nome_do_personagem = "Yami" #@param {type:"string"}
classe = "Arqueira" #@param {type:"string"}
raca = "BloodElf" #@param {type:"string"}
faccao = "HORDA" #@param {type:"string"}

# Atributos
forca = 20 #@param {type:"slider", min:0, max:100}
agilidade = 100 #@param {type:"slider", min:0, max:100}
resistencia = 80 #@param {type:"slider", min:0, max:100}
intelecto = 100 #@param {type:"slider", min:0, max:100}
espiritualidade = 50 #@param {type:"slider", min:0, max:100}

# História do Personagem
historia = "acordou agora e nao lembra de nada kkj" #@param {type:"string"}

# Equipamento
arma = "Arco e flechas" #@param {type:"string"}
armadura = " Armadura leve de couro" #@param {type:"string"}
outros_itens = "Pot de invisibilidade" #@param {type:"string"}


print("Ficha de RPG - World of Warcraft")
print("Nome do Personagem:", nome_do_personagem)
print("Classe:", classe)
print("Raça:", raca)
print("Facção:", faccao)
print("\nAtributos:")
print("Força:", forca)
print("Agilidade:", agilidade)
print("Resistência:", resistencia)
print("Intelecto:", intelecto)
print("Espiritualidade:", espiritualidade)
print("\nHistória do Personagem:", historia)
print("\nEquipamento:")
print("Arma:", arma)
print("Armadura:", armadura)
print("Outros Itens:", outros_itens)
# Out:
# Ficha de RPG - World of Warcraft
# Nome do Personagem: Yami
# Classe: Arqueira
# Raça: BloodElf
# Facção: HORDA
#
# Atributos:
# Força: 20
# Agilidade: 100
# Resistência: 80
# Intelecto: 100
# Espiritualidade: 50
#
# História do Personagem: acordou agora e nao lembra de nada kkj
#
# Equipamento:
# Arma: Arco e flechas
# Armadura:  Armadura leve de couro
# Outros Itens: Pot de invisibilidade
