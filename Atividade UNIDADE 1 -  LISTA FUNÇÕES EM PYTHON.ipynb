# %%
# Solicitar as notas ao usuário
n1 = float(input("Digite a nota da prova 1: "))
n2 = float(input("Digite a nota da prova 2: "))
n3 = float(input("Digite a nota da prova 3: "))
n4 = float(input("Digite a nota da prova 4: "))
n5 = float(input("Digite a nota da prova 5: "))

# Lista de notas dos estudantes

notas = [n1, n2, n3, n4, n5]

# Função regular para calcular a média

def calcular_media(notas):

    total = sum(notas)

    media = total / len(notas)

    return media

# Função lambda para arredondar a média para duas casas decimais

arredondar_media = lambda media: round(media, 2)

# Calcular a média

media = calcular_media(notas)

media_arredondada = arredondar_media(media)

# Verificar se os estudantes foram aprovados

situacao = "Aprovado" if media_arredondada >= 7 else "Reprovado"

# Resultados

print("As notas do(a) aluno(a) são: " , notas)

print("A média do(a) aluno(a) é: " , media_arredondada)

print("A stiuação do(a) aluno(a) é: " , situacao)
# Out:
# Digite a nota da prova 1: 9
# Digite a nota da prova 2: 7
# Digite a nota da prova 3: 8
# Digite a nota da prova 4: 5
# Digite a nota da prova 5: 6
# As notas do(a) aluno(a) são:  [9.0, 7.0, 8.0, 5.0, 6.0]
# A média do(a) aluno(a) é:  7.0
# A stiuação do(a) aluno(a) é:  Aprovado
